# %%
import numpy as np
import itertools
from IPython.display import display, Markdown, Latex, Math

# %matplotlib notebook

import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import tropical

# %%
# A2 = np.array([13, -16, -17, 16, -18])
# b2 = -99
# A1 = np.array([[-1, -16], [-2, -25], [19, -14], [-1, -13], [-20, -10]])
# b1 = np.array([[29], [27], [-5], [24], [29]])

# %%
temp = np.load('saveFile.npz')
A1 = temp['A1']
A2 = temp['A2']
b1 = temp['b1']
b2 = temp['b2']

# %%
Fterms, Gterms = tropical.getTropCoeffs(A1, b1, A2, b2)

# %%
display(Math('F^{(2)} = ' + tropical.displayTropPoly(Fterms)))
print()
display(Math('G^{(2)} = ' + tropical.displayTropPoly(Gterms)))
# Out:
# $$F^{(2)} = (-0.9940772652626038 \odot x_1^{\odot 4.2487268648331815} \odot x_2^{\odot 12.03456099082517}) \oplus (2.1479763018281375 \odot x_1^{\odot 3.9019792079925537} \odot x_2^{\odot 7.978841781616211}) \oplus (0.541838164767853 \odot x_1^{\odot 4.092622824244955} \odot x_2^{\odot 10.050865952407094}) \oplus (0.6120608717976808 \odot x_1^{\odot 4.05808324858078} \odot x_2^{\odot 9.962536820034288})$$
# ...

# %%
fig = plt.figure(figsize=(5, 10))
ax = fig.add_subplot(211, projection='3d')
tropical.newtonPolygon(Fterms, ax)
ax.set_title('Newton polygon of F');

ax = fig.add_subplot(212, projection='3d')
tropical.newtonPolygon(Gterms, ax)
ax.set_title('Newton polygon of G');
# Out:
# <img src="data:image/png;base64,..." width="500">
